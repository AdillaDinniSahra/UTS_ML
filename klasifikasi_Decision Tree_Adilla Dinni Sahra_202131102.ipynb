# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('K02_diabetes.csv')

# %%
data
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
data.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %% [markdown]
# # Mengubah objek menjadi Numerik

# %%
from sklearn.preprocessing import LabelEncoder

for col in ['age', 'hypertension', 'heart_disease', 'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes' ]:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])

print(data['age'].unique(), data['hypertension'].unique(), data['heart_disease'].unique(), data['bmi'].unique(), data['HbA1c_level'].unique(), data['blood_glucose_level'].unique(), data['diabetes'].unique())
# Out:
# [101  75  49  57  97  41  65 100  63  53  74  99  88  36  58  61  26  90
#   93  25  51  66  64  71  62  47  55  94  98  87  50  81  59  24  78  95
#   40  67  42  80  48  34  77  23  28  32  27  76  30  83  68  33  89  96
#   43  79  39  45  38  46   0  54  37  82  52  29  70  60  86  35  91   6
#   69  72  92  10  85  84  73   1  31  56  44   7  13  19   8  22  15   9
#   14  11  21   5  18  12   2  16   4   3  20  17] [0 1] [1 0] [1334 1547 1160 ... 4124 3242 4147] [11  5  4  3 10  8  7  6  0  9  1  2 17 13 16 15 14 12] [ 6  0  9  8  1 12  7  3  5 11  4 10  2 15 13 17 16 14] [0 1]

# %%
data
# Out:
#        gender  age  hypertension  heart_disease smoking_history   bmi  \
# 0      Female  101             0              1           never  1334
# 1      Female   75             0              0         No Info  1547
# 2        Male   49             0              0           never  1547
# 3      Female   57             0              0         current  1160
# 4        Male   97             1              1         current   829
# ...       ...  ...           ...            ...             ...   ...
# 99995  Female  101             0              0         No Info  1547
# 99996  Female   23             0              0         No Info   552
# 99997    Male   87             0              0          former  1598
# 99998  Female   45             0              0           never  2357
# 99999  Female   78             0              0         current  1058
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0               11                    6         0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  int64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  int64
#  6   HbA1c_level          100000 non-null  int64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 6.9+ MB

# %%
data = data.drop('gender',axis=1)

# %%
x = data.drop('diabetes', axis = 1)
y = data['diabetes']

# %%
x
# Out:
#        age  hypertension  heart_disease smoking_history   bmi  HbA1c_level  \
# 0      101             0              1           never  1334           11
# 1       75             0              0         No Info  1547           11
# 2       49             0              0           never  1547            5
# 3       57             0              0         current  1160            4
# 4       97             1              1         current   829            3
# ...    ...           ...            ...             ...   ...          ...
# 99995  101             0              0         No Info  1547            9
# 99996   23             0              0         No Info   552           10
# 99997   87             0              0          former  1598            5
# 99998   45             0              0           never  2357            1
# 99999   78             0              0         current  1058           11
#
#        blood_glucose_level
# 0                        6
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state =0)

# %%
print (x_train)
# Out:
#        age  hypertension  heart_disease smoking_history   bmi  HbA1c_level  \
# 42865  101             0              0         No Info  1547            3
# 91446    8             0              0         No Info   417            6
# 66374   53             0              0         current  1543           11
# 79106   44             0              0         current  1547            0
# 13404   56             0              0           never  1547            9
# ...    ...           ...            ...             ...   ...          ...
# 21243   33             0              0           never  1183            6
# 45891   87             0              0           never  1492           10
# 42613   87             0              0           never  2934           17
# 43567   58             0              0          former  1833            6
# 68268   73             0              0         No Info  1547            2
#
#        blood_glucose_level
# 42865                   10
# ...

# %%
print (y_train)
# Out:
# 42865    0
# 91446    0
# 66374    0
# 79106    0
# 13404    0
#         ..
# 21243    0
# 45891    0
# 42613    1
# 43567    0
# 68268    0
# Name: diabetes, Length: 70000, dtype: int64

# %%
print (x_test)
# Out:
#        age  hypertension  heart_disease smoking_history   bmi  HbA1c_level  \
# 3582    73             0              0           never  1547            3
# 60498   77             0              0           never  1547            3
# 53227   43             0              0         current  2531           11
# 21333   70             0              0         No Info  3189            4
# 3885    31             0              0         No Info   233            1
# ...    ...           ...            ...             ...   ...          ...
# 86308  101             0              1          former  1547            1
# 48870   78             0              0          former  1547            5
# 34940   47             0              0         current  1547            9
# 21964   67             0              0         No Info  1373            5
# 27631   41             0              0           never   983            5
#
#        blood_glucose_level
# 3582                     6
# ...

# %%
print (y_test)
# Out:
# 3582     0
# 60498    0
# 53227    0
# 21333    0
# 3885     0
#         ..
# 86308    0
# 48870    1
# 34940    0
# 21964    0
# 27631    0
# Name: diabetes, Length: 30000, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
model_DT = DecisionTreeClassifier(max_depth=2)

# %%
predict_DT = model_DT.predict

# %% [markdown]
# MODEL

# %%
from sklearn.metrics import accuracy_score
print("akurasi score sebenarnya: ")
# Out:
# akurasi score sebenarnya:

# %%
from sklearn.tree import plot_tree

plt.subplots(figsize=(12,10))
plot_tree 
plt.show()
